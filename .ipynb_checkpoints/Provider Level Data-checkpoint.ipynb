# %%
import numpy as np
import pandas as pd
import glob as glob
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("dark")

# %%
providerdata = pd.read_csv("9.25.2017 ProviderGroupQualityReports.csv", 
                          usecols=["Metricname", "SeenAvg", "NAME"])
pivot = providerdata.pivot(index='NAME', columns='Metricname', values='SeenAvg')
pivot
# Out:
# Metricname                      AAA Screening  \
# NAME
# Alexander MD, Steven                      NaN
# Anderson MD, Greg                      0.6574
# Anderson MD, Rodney                    0.5963
# Bates MD, Jennifer                     0.0667
# Bellingham Bay Medical Center          0.2167
# Billau DO, Shannon                     0.1000
# Binder MD, Richard                     0.7640
# Birch Bay Family Medicine              0.0397
# Bjorseth, Franklin                     0.0430
# Bloom MD, Edward                       0.1920
# Bloom MD, Jessica                      0.2000
# Bloom MD, Steven                          NaN
# Bonner, MD, Ian                        0.1096
# Bowling, Sara                          0.2500
# Bradt DO, Rory                         0.0380
# Brejcha ARNP, Rebecca                     NaN
# Brodsky, Lisa                             NaN
# Burden MD, Margaret                       NaN
# Bylund MD, Erik                        0.4179
# ...
