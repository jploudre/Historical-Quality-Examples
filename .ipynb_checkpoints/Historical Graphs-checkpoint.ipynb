# %% [markdown]
# # Historical Quality Graphs

# %%
import numpy as np
import pandas as pd
import glob as glob
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-whitegrid')
plt.rcParams['lines.linewidth'] = '8'

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<a href="javascript:code_toggle()">Show/Hide Code</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <a href="javascript:code_toggle()">Show/Hide Code</a>.

# %%
files = glob.glob('*.csv')
dfs = []

for file in files:
    df = pd.read_csv(file, 
                     usecols=["lastupdate", "metricname", "ptsseen_avg"],
                    parse_dates=["lastupdate"])
    df['Clinic'] = str(file).strip(".csv")
    dfs.append(df)
    
big_frame = pd.concat(dfs, ignore_index=True)
big_frame = big_frame.pivot_table(index='lastupdate', 
                    columns=['metricname','Clinic'], 
                    values="ptsseen_avg")
# We aren't tracking FIT. 
big_frame = big_frame.drop('FIT', 1)

big_frame['COLORECTAL', 'FCN'].plot(ylim=(30,100), figsize=(4, 6))
big_frame['COLORECTAL', 'NCFP'].plot(ylim=(30,100), figsize=(4, 6) )

# %%
colo1 = big_frame['COLORECTAL', 'FCN'].plot(ylim=(30,100), figsize=(4, 6))
colo1 = big_frame['COLORECTAL', 'NSFM'].plot(ylim=(30,100), figsize=(4, 6))
colo2 = big_frame['COLORECTAL', 'FCN'].plot(ylim=(30,100), figsize=(4, 6))
colo2 = big_frame['COLORECTAL', 'NCFP'].plot(ylim=(30,100), figsize=(4, 6))

# %%
big_frame['MAMMO', 'FCN'].plot(ylim=(30,100), figsize=(4, 6))
big_frame['MAMMO', 'NSFM'].plot(ylim=(30,100), figsize=(4, 6))

# %%
big_frame['MAMMO'].plot(ylim=(30,100), figsize=(4, 6))

# %%
big_frame['PAP'].plot(ylim=(30,100), figsize=(4, 6))

# %%
big_frame['DM-EYE'].plot(ylim=(30,100), figsize=(4, 6))

# %%
big_frame['DM-FOOT'].plot(ylim=(30,100), figsize=(4, 6))

# %%
big_frame['DM-PPSV'].plot(ylim=(30,100), figsize=(4, 6))

# %%
big_frame['MAMMO', 'FCN'].plot(ylim=(30,100), figsize=(4, 6))
big_frame['MAMMO', 'NCFP'].plot(ylim=(30,100), figsize=(4, 6))

# %%
big_frame['MAMMO', 'FCN'].plot(ylim=(30,100), figsize=(4, 6))
big_frame['PAP', 'FCN'].plot(ylim=(30,100), figsize=(4, 6))
big_frame['COLORECTAL', 'FCN'].plot(ylim=(30,100), figsize=(4, 6))

# %%
big_frame['DM-FOOT', 'FCN'].plot(ylim=(30,100), figsize=(4, 6))
big_frame['DM-EYE', 'FCN'].plot(ylim=(30,100), figsize=(4, 6))
big_frame['DM-KIDNEY', 'FCN'].plot(ylim=(30,100), figsize=(4, 6))

# %%
big_frame['TDAP', 'FCN'].plot(ylim=(30,100), figsize=(4, 6))
big_frame['TDAP', 'NCFP'].plot(ylim=(30,100), figsize=(4, 6))

# %%
big_frame['TDAP', 'FCN'].plot(ylim=(30,100), figsize=(4, 6), layout=(2, 3))
big_frame['TDAP', 'NCFP'].plot(ylim=(30,100), figsize=(4, 6), layout=(2, 3)

big_frame['DM-PPSV', 'FCN'].plot(ylim=(30,100), figsize=(4, 6), layout=(2, 3))
big_frame['DM-PPSV', 'NCFP'].plot(ylim=(30,100), figsize=(4, 6), layout=(2, 3))

big_frame['PAP', 'FCN'].plot(ylim=(30,100), figsize=(4, 6), layout=(2, 3))
big_frame['PAP', 'NCFP'].plot(ylim=(30,100), figsize=(4, 6), layout=(2, 3))
big_frame['MAMMO', 'FCN'].plot(ylim=(30,100), figsize=(4, 6), layout=(2, 3))
big_frame['MAMMO', 'NCFP'].plot(ylim=(30,100), figsize=(4, 6), layout=(2, 3))

big_frame['COLORECTAL', 'FCN'].plot(ylim=(30,100), figsize=(4, 6), layout=(2, 3))
big_frame['COLORECTAL', 'NCFP'].plot(ylim=(30,100), figsize=(4, 6), layout=(2, 3))
