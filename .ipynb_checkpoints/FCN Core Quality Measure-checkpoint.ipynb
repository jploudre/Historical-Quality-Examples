# %%
import numpy as np
import pandas as pd
import glob as glob
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
# %matplotlib inline
plt.style.use('fivethirtyeight')
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<a href="javascript:code_toggle()">Show/Hide Code</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <a href="javascript:code_toggle()">Show/Hide Code</a>.

# %%
def get_meridios_quality_history_csv(provider, csv):
    df = pd.read_csv(csv, usecols=["lastupdate", "metricname", "ptsseen_avg"], parse_dates=["lastupdate"])
    df['Provider'] = provider.replace("_", " ")
    # Normalize last update to just a date (not specific run time)
    df['lastupdate'] = df['lastupdate'].apply(lambda dt: datetime.datetime(dt.year, dt.month, dt.day))
    return df

def basic_trendline(dataframe, chart, column, metrictitle, threshold):
    dataframe[column].plot(ax=chart, legend=False)
    chart.set(title=metrictitle, ylim=(0,100), xlabel="")
    chart.axhline(y=threshold, color='g', label='Target', linestyle='--', linewidth=1)
    chart.xaxis.set_major_formatter(plt.NullFormatter())
    
def create_individual_core_quality_graphs(individual, clinic):
    dfs = []
    dfs.append(get_meridios_quality_history_csv('FCN',"FCN.csv"))
    dfs.append(get_meridios_quality_history_csv(clinic, ('./clinic/' + clinic + '.csv')))
    dfs.append(get_meridios_quality_history_csv(individual, ('./provider/' + individual + '.csv')))   
    big_frame = pd.concat(dfs, ignore_index=True)
    big_frame = big_frame.pivot_table(index='lastupdate', columns=['metricname','Provider'], values="ptsseen_avg")
    
    # First Figure: Cancer Screening
    fig, ax = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12,6))
    fig.suptitle(individual.replace('_'," ") + ": Cancer Screening", fontsize=24)
    basic_trendline(big_frame, ax[0], "PAP", "Pap", 85)
    basic_trendline(big_frame, ax[1], "MAMMO", "Mammogram", 80)
    basic_trendline(big_frame, ax[2], "COLORECTAL", "Colorectal", 76)
    ax[2].legend()

    # Second Figure: Diabetes Screening
    fig, ax = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12,6))
    fig.suptitle(individual.replace('_'," ") + ": Diabetes Screening", fontsize=24)
    basic_trendline(big_frame, ax[0], "DM-EYE", "Retinopathy", 80)
    basic_trendline(big_frame, ax[1], "DM-FOOT", "Neuropathy", 80)
    basic_trendline(big_frame, ax[2], "DM-KIDNEY", "Nephropathy", 80)
    ax[2].legend()

    # Third Figure: Immunization    
    fig, ax = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(8,6))
    fig.suptitle(individual.replace('_'," ") + ": Immunization", fontsize=24)
    basic_trendline(big_frame, ax[0], "TDAP", "Tdap", 80)
    basic_trendline(big_frame, ax[1], "DM-PPSV", "Pneumovax (DM)", 80)
    ax[1].legend()

# %%
create_individual_core_quality_graphs("Greg_Anderson", "BellB")
create_individual_core_quality_graphs("Jonathan_Ploudre", "NCFP")

# %%
currentdata = pd.read_csv('./current/ProviderGroupQualityReports.csv', usecols=['NAME', 'Metricname', 'SeenAvg'])
providerlookup = pd.read_csv('./current/provider-clinic.csv', index_col='NAME')
currentdata['Clinic']=currentdata.NAME.map(providerlookup.CLINIC)
corequality = currentdata.loc[currentdata['Metricname'].isin(['Pap Smear Report','Colorectal Cancer Screening (Colonoscopy/Sigmoid/FIT test)','Mammogram Ages 52 -74','Eye exam','Foot Exam','Nephropathy Assessment','TD - Patients >18yrs with TD in last 10 years','Pneumovax - DM patients w/current pneumovax'])]
#sns.stripplot(x='SeenAvg', y='Clinic', hue='Clinic', data=corequality)
sns.factorplot(x='SeenAvg', y='Clinic', data=corequality, row='Metricname', kind="strip")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-c013a0946503> in <module>()
#       4 corequality = currentdata.loc[currentdata['Metricname'].isin(['Pap Smear Report','Colorectal Cancer Screening (Colonoscopy/Sigmoid/FIT test)','Mammogram Ages 52 -74','Eye exam','Foot Exam','Nephropathy Assessment','TD - Patients >18yrs with TD in last 10 years','Pneumovax - DM patients w/current pneumovax'])]
#       5 sns.stripplot(x='SeenAvg', y='Clinic', hue='Clinic', data=corequality)
# ----> 6 sns.factorplot(x='SeenAvg', y='Clinic', data=corequality, row='Metricname', kind="strip")
#
# /Users/jonathan/anaconda/lib/python3.6/site-packages/seaborn/categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3428
#    3429     # Draw the plot onto the facets
# -> 3430     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3431
#    3432     # Special case axis labels for a count type plot
#
# /Users/jonathan/anaconda/lib/python3.6/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     795
#     796         # Finalize the annotations and layout
# --> 797         self._finalize_grid(args[:2])
#     798
#     799         return self
#
# /Users/jonathan/anaconda/lib/python3.6/site-packages/seaborn/axisgrid.py in _finalize_grid(self, axlabels)
#     820         self.set_axis_labels(*axlabels)
#     821         self.set_titles()
# --> 822         self.fig.tight_layout()
#     823
#     824     def facet_axis(self, row_i, col_j):
#
# /Users/jonathan/anaconda/lib/python3.6/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    1753                                          rect=rect)
#    1754
# -> 1755         self.subplots_adjust(**kwargs)
#    1756
#    1757
#
# /Users/jonathan/anaconda/lib/python3.6/site-packages/matplotlib/figure.py in subplots_adjust(self, *args, **kwargs)
#    1618
#    1619         """
# -> 1620         self.subplotpars.update(*args, **kwargs)
#    1621         for ax in self.axes:
#    1622             if not isinstance(ax, SubplotBase):
#
# /Users/jonathan/anaconda/lib/python3.6/site-packages/matplotlib/figure.py in update(self, left, bottom, right, top, wspace, hspace)
#     226             if self.left >= self.right:
#     227                 reset()
# --> 228                 raise ValueError('left cannot be >= right')
#     229
#     230             if self.bottom >= self.top:
#
# ValueError: left cannot be >= right
